# %% [markdown]
# Facial mood detection and song suggestion# Loading Libraries

# %% [markdown]
# # LGMVIP - Data Science Internship October 2022
# # Task - ML Facial recognition to detect mood and suggest songs accordingly
# # Intern - Piyush

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import os
import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

from keras import regularizers
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils.vis_utils import plot_model

from sklearn.metrics import classification_report, confusion_matrix

main_accent_colour = "#b366ff"
dim_colour="darkgrey"
main_palette = ["#FBE5C0", "#DD9A30", "#F88379", "#FF6FC2", "purple", "#D086F6", "#B0D2C2", "#4C5D70", "#6FA2CE", "#382D24", "#3ACF3A", "#7D7D00"]

# %% [markdown]
# # Analyzing

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

row = 48
col = 48
classes = len(os.listdir('../input/fer2013/train/'))

# %%
print("Train Set :")

train_count = []
for folder in os.listdir(train_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(train_dir+folder)), "image")
    train_count.append(len(os.listdir(train_dir+folder)))
    
print()

test_count = []
print("Test Set :")
for folder in os.listdir(test_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(test_dir+folder)), "images")
    test_count.append(len(os.listdir(test_dir+folder)))
# Out:
# Train Set :
# surprise folder contains		 3171 image
# fear folder contains		 4097 image
# angry folder contains		 3995 image
# neutral folder contains		 4965 image
# sad folder contains		 4830 image
# disgust folder contains		 436 image
# happy folder contains		 7215 image
#
# Test Set :
# surprise folder contains		 831 images
# fear folder contains		 1024 images
# angry folder contains		 958 images
# neutral folder contains		 1233 images
# sad folder contains		 1247 images
# disgust folder contains		 111 images
# happy folder contains		 1774 images

# %%
vals = ["disgust"]
palette = {c: dim_colour if c not in vals else main_accent_colour for c in os.listdir(train_dir)}

plt.figure(figsize=(8,4))

ax = sns.barplot(y=os.listdir(train_dir),
                 x=train_count,
                 palette=palette,
                 orientation="horizontal",
).set(title='Train Classes')

plt.show()

print()

ax = sns.barplot(y=os.listdir(test_dir),
                 x=test_count,
                 palette=palette,
                 orientation="horizontal",
).set(title='Test Classes')

plt.show()

print()

plt.figure(figsize=(25,25))

i = 1
for folder in os.listdir(train_dir):
    
    img = load_img((train_dir + folder +'/'+ os.listdir(train_dir + folder)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(folder)
    plt.axis('off')
    i += 1
    
plt.show()

# %% [markdown]
# # Preprocessing

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# # Model

# %%
def get_model(input_size, classes=7):
    
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# 2022-10-16 11:35:53.436238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:53.532998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:53.533815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              31720448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 32,116,743
# Trainable params: 32,116,103
# Non-trainable params: 640
# _________________________________________________________________
# 2022-10-16 11:35:53.535528: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-16 11:35:53.535847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:53.536562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:53.537280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:55.767452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:55.768315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:55.769048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 11:35:55.769645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
plot_model(fernet, show_layer_names=True)

# %% [markdown]
# # Checkpoint

# %%
chk_path = 'ferNet.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

earlystop = EarlyStopping(monitor='val_accuracy', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]
# Out:
# 2022-10-16 11:35:57.162014: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-10-16 11:35:57.162709: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-10-16 11:35:57.164768: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-10-16 11:35:57.384070: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-10-16 11:35:57.384250: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                  validation_data=test_set,
                  epochs=150,
                  callbacks=callbacks,
                  steps_per_epoch=steps_per_epoch,
                  validation_steps=validation_steps)
# Out:
# 2022-10-16 11:35:57.876048: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 2022-10-16 11:35:59.722068: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 448/448 [==============================] - 159s 338ms/step - loss: 4.3177 - accuracy: 0.2784 - val_loss: 5.7444 - val_accuracy: 0.2052
#
# Epoch 00001: val_loss improved from inf to 5.74438, saving model to ferNet.h5
# Epoch 2/150
# 448/448 [==============================] - 40s 90ms/step - loss: 3.5062 - accuracy: 0.3358 - val_loss: 3.1400 - val_accuracy: 0.3930
#
# Epoch 00002: val_loss improved from 5.74438 to 3.13996, saving model to ferNet.h5
# Epoch 3/150
# 448/448 [==============================] - 39s 86ms/step - loss: 3.0066 - accuracy: 0.3671 - val_loss: 2.7934 - val_accuracy: 0.3965
#
# Epoch 00003: val_loss improved from 3.13996 to 2.79344, saving model to ferNet.h5
# Epoch 4/150
# 448/448 [==============================] - 39s 87ms/step - loss: 2.5980 - accuracy: 0.3935 - val_loss: 2.3123 - val_accuracy: 0.4519
#
# Epoch 00004: val_loss improved from 2.79344 to 2.31227, saving model to ferNet.h5
# Epoch 5/150
# 448/448 [==============================] - 39s 87ms/step - loss: 2.2786 - accuracy: 0.4192 - val_loss: 2.0227 - val_accuracy: 0.4746
#
# Epoch 00005: val_loss improved from 2.31227 to 2.02270, saving model to ferNet.h5
# Epoch 6/150
# 448/448 [==============================] - 38s 86ms/step - loss: 2.0303 - accuracy: 0.4422 - val_loss: 1.8722 - val_accuracy: 0.4672
#
# Epoch 00006: val_loss improved from 2.02270 to 1.87223, saving model to ferNet.h5
# Epoch 7/150
# 448/448 [==============================] - 39s 88ms/step - loss: 1.8427 - accuracy: 0.4617 - val_loss: 1.6767 - val_accuracy: 0.5006
#
# Epoch 00007: val_loss improved from 1.87223 to 1.67675, saving model to ferNet.h5
# Epoch 8/150
# 448/448 [==============================] - 39s 87ms/step - loss: 1.7000 - accuracy: 0.4796 - val_loss: 1.5893 - val_accuracy: 0.4980
#
# Epoch 00008: val_loss improved from 1.67675 to 1.58926, saving model to ferNet.h5
# Epoch 9/150
# 448/448 [==============================] - 39s 86ms/step - loss: 1.5826 - accuracy: 0.4945 - val_loss: 1.4398 - val_accuracy: 0.5399
#
# Epoch 00009: val_loss improved from 1.58926 to 1.43981, saving model to ferNet.h5
# Epoch 10/150
# 448/448 [==============================] - 39s 87ms/step - loss: 1.4934 - accuracy: 0.5138 - val_loss: 1.4240 - val_accuracy: 0.5244
#
# Epoch 00010: val_loss improved from 1.43981 to 1.42404, saving model to ferNet.h5
# Epoch 11/150
# 448/448 [==============================] - 38s 86ms/step - loss: 1.4249 - accuracy: 0.5264 - val_loss: 1.4228 - val_accuracy: 0.5128
#
# Epoch 00011: val_loss improved from 1.42404 to 1.42281, saving model to ferNet.h5
# Epoch 12/150
# 448/448 [==============================] - 38s 85ms/step - loss: 1.3656 - accuracy: 0.5422 - val_loss: 1.2577 - val_accuracy: 0.5735
#
# Epoch 00012: val_loss improved from 1.42281 to 1.25775, saving model to ferNet.h5
# Epoch 13/150
# 448/448 [==============================] - 39s 88ms/step - loss: 1.3177 - accuracy: 0.5536 - val_loss: 1.2433 - val_accuracy: 0.5774
#
# Epoch 00013: val_loss improved from 1.25775 to 1.24330, saving model to ferNet.h5
# Epoch 14/150
# 448/448 [==============================] - 39s 88ms/step - loss: 1.2701 - accuracy: 0.5648 - val_loss: 1.2079 - val_accuracy: 0.5897
#
# Epoch 00014: val_loss improved from 1.24330 to 1.20789, saving model to ferNet.h5
# Epoch 15/150
# 448/448 [==============================] - 38s 85ms/step - loss: 1.2325 - accuracy: 0.5783 - val_loss: 1.2225 - val_accuracy: 0.5875
#
# Epoch 00015: val_loss did not improve from 1.20789
# Epoch 16/150
# 448/448 [==============================] - 38s 86ms/step - loss: 1.1958 - accuracy: 0.5887 - val_loss: 1.1696 - val_accuracy: 0.5968
#
# Epoch 00016: val_loss improved from 1.20789 to 1.16955, saving model to ferNet.h5
# Epoch 17/150
# 448/448 [==============================] - 38s 85ms/step - loss: 1.1623 - accuracy: 0.6008 - val_loss: 1.1424 - val_accuracy: 0.6070
#
# Epoch 00017: val_loss improved from 1.16955 to 1.14238, saving model to ferNet.h5
# Epoch 18/150
# 448/448 [==============================] - 38s 86ms/step - loss: 1.1428 - accuracy: 0.6072 - val_loss: 1.1254 - val_accuracy: 0.6147
#
# Epoch 00018: val_loss improved from 1.14238 to 1.12540, saving model to ferNet.h5
# Epoch 19/150
# 448/448 [==============================] - 39s 86ms/step - loss: 1.1098 - accuracy: 0.6184 - val_loss: 1.1596 - val_accuracy: 0.6062
#
# Epoch 00019: val_loss did not improve from 1.12540
# Epoch 20/150
# 448/448 [==============================] - 38s 86ms/step - loss: 1.0786 - accuracy: 0.6309 - val_loss: 1.1415 - val_accuracy: 0.6130
#
# Epoch 00020: val_loss did not improve from 1.12540
# Epoch 21/150
# 448/448 [==============================] - 38s 85ms/step - loss: 1.0582 - accuracy: 0.6400 - val_loss: 1.1801 - val_accuracy: 0.5963
#
# Epoch 00021: val_loss did not improve from 1.12540
# Epoch 22/150
# 448/448 [==============================] - 39s 86ms/step - loss: 1.0380 - accuracy: 0.6460 - val_loss: 1.1137 - val_accuracy: 0.6189
#
# Epoch 00022: val_loss improved from 1.12540 to 1.11370, saving model to ferNet.h5
# Epoch 23/150
# 448/448 [==============================] - 39s 86ms/step - loss: 1.0193 - accuracy: 0.6539 - val_loss: 1.1325 - val_accuracy: 0.6207
#
# Epoch 00023: val_loss did not improve from 1.11370
# Epoch 24/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.9822 - accuracy: 0.6655 - val_loss: 1.1396 - val_accuracy: 0.6233
#
# Epoch 00024: val_loss did not improve from 1.11370
# Epoch 25/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9681 - accuracy: 0.6766 - val_loss: 1.0868 - val_accuracy: 0.6334
#
# Epoch 00025: val_loss improved from 1.11370 to 1.08680, saving model to ferNet.h5
# Epoch 26/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9482 - accuracy: 0.6847 - val_loss: 1.0990 - val_accuracy: 0.6282
#
# Epoch 00026: val_loss did not improve from 1.08680
# Epoch 27/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.9321 - accuracy: 0.6874 - val_loss: 1.0983 - val_accuracy: 0.6309
#
# Epoch 00027: val_loss did not improve from 1.08680
# Epoch 28/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.9039 - accuracy: 0.7003 - val_loss: 1.1280 - val_accuracy: 0.6364
#
# Epoch 00028: val_loss did not improve from 1.08680
# Epoch 29/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.8955 - accuracy: 0.7041 - val_loss: 1.1032 - val_accuracy: 0.6363
#
# Epoch 00029: val_loss did not improve from 1.08680
# Epoch 30/150
# 448/448 [==============================] - 37s 84ms/step - loss: 0.8663 - accuracy: 0.7121 - val_loss: 1.1104 - val_accuracy: 0.6408
#
# Epoch 00030: val_loss did not improve from 1.08680
# Epoch 31/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.8616 - accuracy: 0.7144 - val_loss: 1.0922 - val_accuracy: 0.6437
#
# Epoch 00031: val_loss did not improve from 1.08680
# Epoch 32/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.8379 - accuracy: 0.7211 - val_loss: 1.1036 - val_accuracy: 0.6413
#
# Epoch 00032: val_loss did not improve from 1.08680
# Epoch 33/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.8218 - accuracy: 0.7285 - val_loss: 1.1112 - val_accuracy: 0.6398
#
# Epoch 00033: val_loss did not improve from 1.08680
# Epoch 34/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.8037 - accuracy: 0.7381 - val_loss: 1.0786 - val_accuracy: 0.6486
#
# Epoch 00034: val_loss improved from 1.08680 to 1.07859, saving model to ferNet.h5
# Epoch 35/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.7899 - accuracy: 0.7417 - val_loss: 1.1445 - val_accuracy: 0.6409
#
# Epoch 00035: val_loss did not improve from 1.07859
# Epoch 36/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.7760 - accuracy: 0.7490 - val_loss: 1.1698 - val_accuracy: 0.6433
#
# Epoch 00036: val_loss did not improve from 1.07859
# Epoch 37/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.7647 - accuracy: 0.7533 - val_loss: 1.1083 - val_accuracy: 0.6487
#
# Epoch 00037: val_loss did not improve from 1.07859
# Epoch 38/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.7403 - accuracy: 0.7577 - val_loss: 1.1628 - val_accuracy: 0.6401
#
# Epoch 00038: val_loss did not improve from 1.07859
# Epoch 39/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.7426 - accuracy: 0.7607 - val_loss: 1.2060 - val_accuracy: 0.6434
#
# Epoch 00039: val_loss did not improve from 1.07859
# Epoch 40/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.7203 - accuracy: 0.7652 - val_loss: 1.1660 - val_accuracy: 0.6423
#
# Epoch 00040: val_loss did not improve from 1.07859
# Epoch 41/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.7167 - accuracy: 0.7722 - val_loss: 1.1662 - val_accuracy: 0.6528
#
# Epoch 00041: val_loss did not improve from 1.07859
# Epoch 42/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.7026 - accuracy: 0.7772 - val_loss: 1.1978 - val_accuracy: 0.6420
#
# Epoch 00042: val_loss did not improve from 1.07859
# Epoch 43/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.6851 - accuracy: 0.7860 - val_loss: 1.1823 - val_accuracy: 0.6505
#
# Epoch 00043: val_loss did not improve from 1.07859
# Epoch 44/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.6757 - accuracy: 0.7848 - val_loss: 1.1525 - val_accuracy: 0.6500
#
# Epoch 00044: val_loss did not improve from 1.07859
# Epoch 45/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.6716 - accuracy: 0.7879 - val_loss: 1.1649 - val_accuracy: 0.6543
#
# Epoch 00045: val_loss did not improve from 1.07859
# Epoch 46/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.6584 - accuracy: 0.7940 - val_loss: 1.1939 - val_accuracy: 0.6459
#
# Epoch 00046: val_loss did not improve from 1.07859
# Epoch 47/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.6606 - accuracy: 0.7904 - val_loss: 1.1611 - val_accuracy: 0.6589
#
# Epoch 00047: val_loss did not improve from 1.07859
# Epoch 48/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.6439 - accuracy: 0.7991 - val_loss: 1.1343 - val_accuracy: 0.6635
#
# Epoch 00048: val_loss did not improve from 1.07859
# Epoch 49/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.6404 - accuracy: 0.8002 - val_loss: 1.1776 - val_accuracy: 0.6589
#
# Epoch 00049: val_loss did not improve from 1.07859
# Epoch 50/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.6183 - accuracy: 0.8069 - val_loss: 1.2611 - val_accuracy: 0.6489
#
# Epoch 00050: val_loss did not improve from 1.07859
# Epoch 51/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.6081 - accuracy: 0.8113 - val_loss: 1.1682 - val_accuracy: 0.6554
#
# Epoch 00051: val_loss did not improve from 1.07859
# Epoch 52/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.6055 - accuracy: 0.8125 - val_loss: 1.2609 - val_accuracy: 0.6463
#
# Epoch 00052: val_loss did not improve from 1.07859
# Epoch 53/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.5970 - accuracy: 0.8137 - val_loss: 1.2064 - val_accuracy: 0.6554
#
# Epoch 00053: val_loss did not improve from 1.07859
# Epoch 54/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.5926 - accuracy: 0.8175 - val_loss: 1.2515 - val_accuracy: 0.6500
#
# Epoch 00054: val_loss did not improve from 1.07859
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 55/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.5341 - accuracy: 0.8390 - val_loss: 1.2172 - val_accuracy: 0.6621
#
# Epoch 00055: val_loss did not improve from 1.07859
# Epoch 56/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.5153 - accuracy: 0.8468 - val_loss: 1.2273 - val_accuracy: 0.6656
#
# Epoch 00056: val_loss did not improve from 1.07859
# Epoch 57/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.5084 - accuracy: 0.8489 - val_loss: 1.2085 - val_accuracy: 0.6638
#
# Epoch 00057: val_loss did not improve from 1.07859
# Epoch 58/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.4982 - accuracy: 0.8527 - val_loss: 1.2062 - val_accuracy: 0.6646
#
# Epoch 00058: val_loss did not improve from 1.07859
# Epoch 59/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.4811 - accuracy: 0.8575 - val_loss: 1.2118 - val_accuracy: 0.6710
#
# Epoch 00059: val_loss did not improve from 1.07859
# Epoch 60/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4856 - accuracy: 0.8536 - val_loss: 1.2106 - val_accuracy: 0.6666
#
# Epoch 00060: val_loss did not improve from 1.07859
# Epoch 61/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.4675 - accuracy: 0.8625 - val_loss: 1.2347 - val_accuracy: 0.6678
#
# Epoch 00061: val_loss did not improve from 1.07859
# Epoch 62/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.4695 - accuracy: 0.8601 - val_loss: 1.2238 - val_accuracy: 0.6703
#
# Epoch 00062: val_loss did not improve from 1.07859
# Epoch 63/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.4618 - accuracy: 0.8645 - val_loss: 1.2369 - val_accuracy: 0.6669
#
# Epoch 00063: val_loss did not improve from 1.07859
# Epoch 64/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.4524 - accuracy: 0.8641 - val_loss: 1.2512 - val_accuracy: 0.6705
#
# Epoch 00064: val_loss did not improve from 1.07859
# Epoch 65/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.4619 - accuracy: 0.8632 - val_loss: 1.2210 - val_accuracy: 0.6719
#
# Epoch 00065: val_loss did not improve from 1.07859
# Epoch 66/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4470 - accuracy: 0.8673 - val_loss: 1.2487 - val_accuracy: 0.6717
#
# Epoch 00066: val_loss did not improve from 1.07859
# Epoch 67/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4443 - accuracy: 0.8711 - val_loss: 1.2498 - val_accuracy: 0.6709
#
# Epoch 00067: val_loss did not improve from 1.07859
# Epoch 68/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.4446 - accuracy: 0.8714 - val_loss: 1.2552 - val_accuracy: 0.6676
#
# Epoch 00068: val_loss did not improve from 1.07859
# Epoch 69/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.4374 - accuracy: 0.8711 - val_loss: 1.2692 - val_accuracy: 0.6751
#
# Epoch 00069: val_loss did not improve from 1.07859
# Epoch 70/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.4344 - accuracy: 0.8718 - val_loss: 1.2444 - val_accuracy: 0.6731
#
# Epoch 00070: val_loss did not improve from 1.07859
# Epoch 71/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4339 - accuracy: 0.8722 - val_loss: 1.2612 - val_accuracy: 0.6738
#
# Epoch 00071: val_loss did not improve from 1.07859
# Epoch 72/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4293 - accuracy: 0.8737 - val_loss: 1.2926 - val_accuracy: 0.6731
#
# Epoch 00072: val_loss did not improve from 1.07859
# Epoch 73/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.4204 - accuracy: 0.8752 - val_loss: 1.2746 - val_accuracy: 0.6703
#
# Epoch 00073: val_loss did not improve from 1.07859
# Epoch 74/150
# 448/448 [==============================] - 40s 90ms/step - loss: 0.4176 - accuracy: 0.8776 - val_loss: 1.2669 - val_accuracy: 0.6749
#
# Epoch 00074: val_loss did not improve from 1.07859
# Epoch 75/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.4090 - accuracy: 0.8807 - val_loss: 1.3053 - val_accuracy: 0.6761
#
# Epoch 00075: val_loss did not improve from 1.07859
# Epoch 76/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.4155 - accuracy: 0.8797 - val_loss: 1.2719 - val_accuracy: 0.6742
#
# Epoch 00076: val_loss did not improve from 1.07859
# Epoch 77/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.4057 - accuracy: 0.8813 - val_loss: 1.2766 - val_accuracy: 0.6717
#
# Epoch 00077: val_loss did not improve from 1.07859
# Epoch 78/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4078 - accuracy: 0.8814 - val_loss: 1.2885 - val_accuracy: 0.6758
#
# Epoch 00078: val_loss did not improve from 1.07859
# Epoch 79/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3973 - accuracy: 0.8844 - val_loss: 1.3003 - val_accuracy: 0.6696
#
# Epoch 00079: val_loss did not improve from 1.07859
# Epoch 80/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3998 - accuracy: 0.8828 - val_loss: 1.2817 - val_accuracy: 0.6780
#
# Epoch 00080: val_loss did not improve from 1.07859
# Epoch 81/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.4005 - accuracy: 0.8812 - val_loss: 1.2850 - val_accuracy: 0.6744
#
# Epoch 00081: val_loss did not improve from 1.07859
# Epoch 82/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3925 - accuracy: 0.8858 - val_loss: 1.2601 - val_accuracy: 0.6784
#
# Epoch 00082: val_loss did not improve from 1.07859
# Epoch 83/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.3937 - accuracy: 0.8856 - val_loss: 1.3086 - val_accuracy: 0.6742
#
# Epoch 00083: val_loss did not improve from 1.07859
# Epoch 84/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3870 - accuracy: 0.8873 - val_loss: 1.2780 - val_accuracy: 0.6786
#
# Epoch 00084: val_loss did not improve from 1.07859
# Epoch 85/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3847 - accuracy: 0.8886 - val_loss: 1.2671 - val_accuracy: 0.6744
#
# Epoch 00085: val_loss did not improve from 1.07859
# Epoch 86/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.3872 - accuracy: 0.8872 - val_loss: 1.3108 - val_accuracy: 0.6734
#
# Epoch 00086: val_loss did not improve from 1.07859
# Epoch 87/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.3793 - accuracy: 0.8897 - val_loss: 1.2740 - val_accuracy: 0.6727
#
# Epoch 00087: val_loss did not improve from 1.07859
# Epoch 88/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3793 - accuracy: 0.8882 - val_loss: 1.2823 - val_accuracy: 0.6748
#
# Epoch 00088: val_loss did not improve from 1.07859
# Epoch 89/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3788 - accuracy: 0.8877 - val_loss: 1.2903 - val_accuracy: 0.6741
#
# Epoch 00089: val_loss did not improve from 1.07859
# Epoch 90/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3781 - accuracy: 0.8910 - val_loss: 1.3173 - val_accuracy: 0.6762
#
# Epoch 00090: val_loss did not improve from 1.07859
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 91/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3634 - accuracy: 0.8951 - val_loss: 1.3137 - val_accuracy: 0.6740
#
# Epoch 00091: val_loss did not improve from 1.07859
# Epoch 92/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3593 - accuracy: 0.8986 - val_loss: 1.2931 - val_accuracy: 0.6744
#
# Epoch 00092: val_loss did not improve from 1.07859
# Epoch 93/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3613 - accuracy: 0.8961 - val_loss: 1.2969 - val_accuracy: 0.6754
#
# Epoch 00093: val_loss did not improve from 1.07859
# Epoch 94/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3518 - accuracy: 0.8998 - val_loss: 1.2996 - val_accuracy: 0.6754
#
# Epoch 00094: val_loss did not improve from 1.07859
# Epoch 95/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3566 - accuracy: 0.8982 - val_loss: 1.2979 - val_accuracy: 0.6745
#
# Epoch 00095: val_loss did not improve from 1.07859
# Epoch 96/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.3521 - accuracy: 0.8982 - val_loss: 1.3129 - val_accuracy: 0.6747
#
# Epoch 00096: val_loss did not improve from 1.07859
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 97/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3534 - accuracy: 0.8983 - val_loss: 1.3134 - val_accuracy: 0.6748
#
# Epoch 00097: val_loss did not improve from 1.07859
# Epoch 98/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3571 - accuracy: 0.8972 - val_loss: 1.3068 - val_accuracy: 0.6749
#
# Epoch 00098: val_loss did not improve from 1.07859
# Epoch 99/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3533 - accuracy: 0.8988 - val_loss: 1.3106 - val_accuracy: 0.6756
#
# Epoch 00099: val_loss did not improve from 1.07859
# Epoch 100/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3485 - accuracy: 0.9014 - val_loss: 1.3106 - val_accuracy: 0.6744
#
# Epoch 00100: val_loss did not improve from 1.07859
# Epoch 101/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3523 - accuracy: 0.8979 - val_loss: 1.3096 - val_accuracy: 0.6748
#
# Epoch 00101: val_loss did not improve from 1.07859
# Epoch 102/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3514 - accuracy: 0.8991 - val_loss: 1.3067 - val_accuracy: 0.6730
#
# Epoch 00102: val_loss did not improve from 1.07859
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# Epoch 103/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3528 - accuracy: 0.8972 - val_loss: 1.3075 - val_accuracy: 0.6733
#
# Epoch 00103: val_loss did not improve from 1.07859
# Epoch 104/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3487 - accuracy: 0.8999 - val_loss: 1.3086 - val_accuracy: 0.6733
#
# Epoch 00104: val_loss did not improve from 1.07859
# Epoch 105/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3536 - accuracy: 0.8981 - val_loss: 1.3052 - val_accuracy: 0.6731
#
# Epoch 00105: val_loss did not improve from 1.07859
# Epoch 106/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3498 - accuracy: 0.9008 - val_loss: 1.3079 - val_accuracy: 0.6740
#
# Epoch 00106: val_loss did not improve from 1.07859
# Epoch 107/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3499 - accuracy: 0.8978 - val_loss: 1.3055 - val_accuracy: 0.6740
#
# Epoch 00107: val_loss did not improve from 1.07859
# Epoch 108/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3493 - accuracy: 0.9013 - val_loss: 1.3074 - val_accuracy: 0.6740
#
# Epoch 00108: val_loss did not improve from 1.07859
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# Epoch 109/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3515 - accuracy: 0.9001 - val_loss: 1.3079 - val_accuracy: 0.6742
#
# Epoch 00109: val_loss did not improve from 1.07859
# Epoch 110/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3457 - accuracy: 0.9011 - val_loss: 1.3087 - val_accuracy: 0.6741
#
# Epoch 00110: val_loss did not improve from 1.07859
# Epoch 111/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3515 - accuracy: 0.9001 - val_loss: 1.3083 - val_accuracy: 0.6737
#
# Epoch 00111: val_loss did not improve from 1.07859
# Epoch 112/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3458 - accuracy: 0.9007 - val_loss: 1.3073 - val_accuracy: 0.6741
#
# Epoch 00112: val_loss did not improve from 1.07859
# Epoch 113/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.3519 - accuracy: 0.9000 - val_loss: 1.3072 - val_accuracy: 0.6740
#
# Epoch 00113: val_loss did not improve from 1.07859
# Epoch 114/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3532 - accuracy: 0.8986 - val_loss: 1.3080 - val_accuracy: 0.6737
#
# Epoch 00114: val_loss did not improve from 1.07859
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# Epoch 115/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3496 - accuracy: 0.8997 - val_loss: 1.3063 - val_accuracy: 0.6741
#
# Epoch 00115: val_loss did not improve from 1.07859
# Epoch 116/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3502 - accuracy: 0.9005 - val_loss: 1.3085 - val_accuracy: 0.6745
#
# Epoch 00116: val_loss did not improve from 1.07859
# Epoch 117/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3535 - accuracy: 0.8994 - val_loss: 1.3060 - val_accuracy: 0.6745
#
# Epoch 00117: val_loss did not improve from 1.07859
# Epoch 118/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3558 - accuracy: 0.8982 - val_loss: 1.3069 - val_accuracy: 0.6742
#
# Epoch 00118: val_loss did not improve from 1.07859
# Epoch 119/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3537 - accuracy: 0.8976 - val_loss: 1.3059 - val_accuracy: 0.6740
#
# Epoch 00119: val_loss did not improve from 1.07859
# Epoch 120/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3531 - accuracy: 0.9008 - val_loss: 1.3054 - val_accuracy: 0.6744
#
# Epoch 00120: val_loss did not improve from 1.07859
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# Epoch 121/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3566 - accuracy: 0.8988 - val_loss: 1.3074 - val_accuracy: 0.6741
#
# Epoch 00121: val_loss did not improve from 1.07859
# Epoch 122/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.3509 - accuracy: 0.8995 - val_loss: 1.3075 - val_accuracy: 0.6741
#
# Epoch 00122: val_loss did not improve from 1.07859
# Epoch 123/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.3525 - accuracy: 0.8990 - val_loss: 1.3068 - val_accuracy: 0.6742
#
# Epoch 00123: val_loss did not improve from 1.07859
# Epoch 124/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3484 - accuracy: 0.9019 - val_loss: 1.3086 - val_accuracy: 0.6741
#
# Epoch 00124: val_loss did not improve from 1.07859
# Epoch 125/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3535 - accuracy: 0.8980 - val_loss: 1.3082 - val_accuracy: 0.6741
#
# Epoch 00125: val_loss did not improve from 1.07859
# Epoch 126/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.3559 - accuracy: 0.8968 - val_loss: 1.3063 - val_accuracy: 0.6742
#
# Epoch 00126: val_loss did not improve from 1.07859
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
# Epoch 127/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3512 - accuracy: 0.8976 - val_loss: 1.3075 - val_accuracy: 0.6742
#
# Epoch 00127: val_loss did not improve from 1.07859
# Epoch 128/150
# 448/448 [==============================] - 41s 91ms/step - loss: 0.3500 - accuracy: 0.9013 - val_loss: 1.3071 - val_accuracy: 0.6742
#
# Epoch 00128: val_loss did not improve from 1.07859
# Epoch 129/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3531 - accuracy: 0.8978 - val_loss: 1.3068 - val_accuracy: 0.6740
#
# Epoch 00129: val_loss did not improve from 1.07859
# Epoch 130/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3519 - accuracy: 0.8980 - val_loss: 1.3076 - val_accuracy: 0.6741
#
# Epoch 00130: val_loss did not improve from 1.07859
# Epoch 131/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3544 - accuracy: 0.8991 - val_loss: 1.3063 - val_accuracy: 0.6742
#
# Epoch 00131: val_loss did not improve from 1.07859
# Epoch 132/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3518 - accuracy: 0.9000 - val_loss: 1.3065 - val_accuracy: 0.6745
#
# Epoch 00132: val_loss did not improve from 1.07859
#
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
# Epoch 133/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3441 - accuracy: 0.9004 - val_loss: 1.3089 - val_accuracy: 0.6742
#
# Epoch 00133: val_loss did not improve from 1.07859
# Epoch 134/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3546 - accuracy: 0.8972 - val_loss: 1.3110 - val_accuracy: 0.6742
#
# Epoch 00134: val_loss did not improve from 1.07859
# Epoch 135/150
# 448/448 [==============================] - 40s 90ms/step - loss: 0.3454 - accuracy: 0.9021 - val_loss: 1.3087 - val_accuracy: 0.6738
#
# Epoch 00135: val_loss did not improve from 1.07859
# Epoch 136/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.3506 - accuracy: 0.9011 - val_loss: 1.3067 - val_accuracy: 0.6740
#
# Epoch 00136: val_loss did not improve from 1.07859
# Epoch 137/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3521 - accuracy: 0.8982 - val_loss: 1.3073 - val_accuracy: 0.6740
#
# Epoch 00137: val_loss did not improve from 1.07859
# Epoch 138/150
# 448/448 [==============================] - 40s 88ms/step - loss: 0.3449 - accuracy: 0.9006 - val_loss: 1.3084 - val_accuracy: 0.6740
#
# Epoch 00138: val_loss did not improve from 1.07859
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 1.0239999126415712e-11.
# Epoch 139/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3551 - accuracy: 0.8977 - val_loss: 1.3080 - val_accuracy: 0.6742
#
# Epoch 00139: val_loss did not improve from 1.07859
# Epoch 140/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3552 - accuracy: 0.8981 - val_loss: 1.3088 - val_accuracy: 0.6741
#
# Epoch 00140: val_loss did not improve from 1.07859
# Epoch 141/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.3489 - accuracy: 0.9014 - val_loss: 1.3071 - val_accuracy: 0.6740
#
# Epoch 00141: val_loss did not improve from 1.07859
# Epoch 142/150
# 448/448 [==============================] - 38s 86ms/step - loss: 0.3520 - accuracy: 0.8958 - val_loss: 1.3075 - val_accuracy: 0.6742
#
# Epoch 00142: val_loss did not improve from 1.07859
# Epoch 143/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3536 - accuracy: 0.8979 - val_loss: 1.3092 - val_accuracy: 0.6744
#
# Epoch 00143: val_loss did not improve from 1.07859
# Epoch 144/150
# 448/448 [==============================] - 39s 88ms/step - loss: 0.3549 - accuracy: 0.8969 - val_loss: 1.3070 - val_accuracy: 0.6738
#
# Epoch 00144: val_loss did not improve from 1.07859
#
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 2.0479997905886727e-12.
# Epoch 145/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3503 - accuracy: 0.8973 - val_loss: 1.3049 - val_accuracy: 0.6747
#
# Epoch 00145: val_loss did not improve from 1.07859
# Epoch 146/150
# 448/448 [==============================] - 39s 86ms/step - loss: 0.3538 - accuracy: 0.8996 - val_loss: 1.3075 - val_accuracy: 0.6742
#
# Epoch 00146: val_loss did not improve from 1.07859
# Epoch 147/150
# 448/448 [==============================] - 39s 87ms/step - loss: 0.3513 - accuracy: 0.8987 - val_loss: 1.3056 - val_accuracy: 0.6742
#
# Epoch 00147: val_loss did not improve from 1.07859
# Epoch 148/150
# 448/448 [==============================] - 38s 84ms/step - loss: 0.3458 - accuracy: 0.9012 - val_loss: 1.3054 - val_accuracy: 0.6740
#
# Epoch 00148: val_loss did not improve from 1.07859
# Epoch 149/150
# 448/448 [==============================] - 38s 85ms/step - loss: 0.3509 - accuracy: 0.8996 - val_loss: 1.3090 - val_accuracy: 0.6737
#
# Epoch 00149: val_loss did not improve from 1.07859
# Epoch 150/150
# 448/448 [==============================] - 40s 89ms/step - loss: 0.3539 - accuracy: 0.8981 - val_loss: 1.3070 - val_accuracy: 0.6741
#
# Epoch 00150: val_loss did not improve from 1.07859
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 4.0959995811773456e-13.

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 32s 70ms/step - loss: 0.1915 - accuracy: 0.9657
# 113/113 [==============================] - 6s 51ms/step - loss: 1.3067 - accuracy: 0.6741
# final train accuracy = 96.57 , validation accuracy = 67.41

# %% [markdown]
# # Result

# %%
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[ 549   47  549 1027  717  671  435]
#  [  70    5   71  117   60   71   42]
#  [ 538   65  600 1052  683  742  417]
#  [ 991  122  934 1813 1296 1231  828]
#  [ 652   79  700 1246  886  828  574]
#  [ 691   70  674 1224  852  793  526]
#  [ 458   40  468  798  540  522  345]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14      3995
#      disgust       0.01      0.01      0.01       436
#         fear       0.15      0.15      0.15      4097
#        happy       0.25      0.25      0.25      7215
#      neutral       0.18      0.18      0.18      4965
#          sad       0.16      0.16      0.16      4830
#     surprise       0.11      0.11      0.11      3171
#
#     accuracy                           0.17     28709
#    macro avg       0.14      0.14      0.14     28709
# weighted avg       0.17      0.17      0.17     28709

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[137  10 119 235 181 169 107]
#  [  9   1  10  26  21  28  16]
#  [157  13 136 249 190 172 107]
#  [275  20 205 428 328 312 206]
#  [175   8 136 319 236 223 136]
#  [177   9 142 321 237 213 148]
#  [108  13 108 183 164 142 113]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.13      0.14      0.14       958
#      disgust       0.01      0.01      0.01       111
#         fear       0.16      0.13      0.14      1024
#        happy       0.24      0.24      0.24      1774
#      neutral       0.17      0.19      0.18      1233
#          sad       0.17      0.17      0.17      1247
#     surprise       0.14      0.14      0.14       831
#
#     accuracy                           0.18      7178
#    macro avg       0.15      0.15      0.15      7178
# weighted avg       0.18      0.18      0.18      7178

# %% [markdown]
# # Recommending Music

# %%
mood_music = pd.read_csv("../input/spotify-music-data-to-identify-the-moods/data_moods.csv")
mood_music = mood_music[['name','artist','mood']]
mood_music.head()
# Out:
#                                           name          artist       mood
# 0                                         1999          Prince      Happy
# 1                                           23  Blonde Redhead        Sad
# 2                                     9 Crimes     Damien Rice        Sad
# 3                               99 Luftballons            Nena      Happy
# 4  A Boy Brushed Red Living In Black And White       Underoath  Energetic

# %%
image = cv2.imread('../input/fer2013/test/happy/PrivateTest_10077120.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(image,cmap='gray')
plt.show()

# %%
image = cv2.resize(image,(48,48))
img=np.array(image)
img=img.reshape(1,48,48,1)
predict_x=fernet.predict(img) 
result=np.argmax(predict_x,axis=1)
result[0]
# Out:
# 3

# %%
if(result[0]==0 or result[0]==1 or result[0]==2 ):
    #for angery,disgust,fear
    filter1=mood_music['mood']=='Calm'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==3 or result[0]==4):
    #for happy, neutral
    filter1=mood_music['mood']=='Happy'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==5):
       #for Sad
    filter1=mood_music['mood']=='Sad'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==6):
     #for surprise
    filter1=mood_music['mood']=='Energetic'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
# Out:
#    index                                               name  \
# 0    321  Lola - Live at Providence Civic Center, Provid...
# 1    207                               Geno - 2000 Remaster
# 2    149                                 Down On The Corner
# 3     72                                          Body Rock
# 4    317                                    Little Lion Man
#
#                          artist   mood
# 0                     The Kinks  Happy
# 1        Dexys Midnight Runners  Happy
# 2  Creedence Clearwater Revival  Happy
# 3                 Bingo Players  Happy
# 4                Mumford & Sons  Happy
